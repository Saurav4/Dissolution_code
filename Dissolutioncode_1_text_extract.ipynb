# %%
pwd
# Out:
# 'C:\\Users\\Saurav\\Dropbox\\Saurav\\dissolution announcements'

# %%
import os

# %%
#extracting text from the pdf AMP_Sanmar.pdf
# !pip install tika
from tika import parser

raw = parser.from_file('../dissolution announcements/AMP_Sanmar.pdf')   
print(raw['content'])
# Out:
# ...
# 2020-05-26 11:50:01,319 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# Page 1 of 1 © 2020 Factiva, Inc. All rights reserved.
#
# Reliance Cap to buy AMP Sanmar for Rs 100 crore ; Reliance Capital will acquire AMP Sanmar Life
# Insurance Company for...
#
# FRENY PATEL & KAUSIK DATTA Mumbai
# 223 words
# 17 August 2005
# Business Standard
# BSTN
# 1
# English
# (c) 2005 Business Standard Ltd.
# Reliance Capital will acquire AMP Sanmar Life Insurance Company for Rs 100 crore. Since the
# Chennai-based life insurance entity has net free assets of Rs 60-65 crore, Reliance Cap will pay a premium
# of Rs 35-40 crore.
#
# Net free assets essentially denote the book value of an insurance company, calculated after deducting losses
# from its share capital. AMP Sanmar has a capital base of Rs 217.5 crore.
#
# The non-banking finance arm of the Anil Dhirubhai Ambani Enterprise (ADAE) had initially decided to acquire
# ...

# %%
#extracting text from all the pdfs from Dissolution Announcements folder
for dirpath, dirnames, files in os.walk('.'):
    for file_name in files:
        # !pip install tika
        from tika import parser

        raw = parser.from_file(os.path.join(dirpath,file_name))   
        print(raw['content'])
# Out:
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Page 1 of 1 © 2020 Factiva, Inc. All rights reserved.
#
# Reliance Cap to buy AMP Sanmar for Rs 100 crore ; Reliance Capital will acquire AMP Sanmar Life
# Insurance Company for...
#
# FRENY PATEL & KAUSIK DATTA Mumbai
# 223 words
# 17 August 2005
# Business Standard
# BSTN
# 1
# English
# (c) 2005 Business Standard Ltd.
# Reliance Capital will acquire AMP Sanmar Life Insurance Company for Rs 100 crore. Since the
# Chennai-based life insurance entity has net free assets of Rs 60-65 crore, Reliance Cap will pay a premium
# of Rs 35-40 crore.
#
# Net free assets essentially denote the book value of an insurance company, calculated after deducting losses
# from its share capital. AMP Sanmar has a capital base of Rs 217.5 crore.
#
# The non-banking finance arm of the Anil Dhirubhai Ambani Enterprise (ADAE) had initially decided to acquire
# ...
